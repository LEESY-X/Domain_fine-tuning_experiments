# %% [markdown]
# # Study 2 - Multi-task and Multi-model
#
# 기본 실행 모드는 전체 논문 실험용 `PAPER`입니다. 짧은 점검만 필요할 때 `SMOKE`로 변경하세요.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks': ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))
from src.suite import precheck, run_study, aggregate
precheck()
# Out:
# {'time': '2026-06-24T19:24:34+09:00',
#  'python': '3.10.19 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 16:41:31) [MSC v.1929 64 bit (AMD64)]',
#  'torch': '2.11.0.dev20260119+cu128',
#  'cuda_runtime': '12.8',
#  'cuda_available': True,
#  'gpu': 'NVIDIA GeForce RTX 5070 Ti',
#  'gpu_memory_gb': 15.92,
#  'transformers': '5.9.0',
#  'datasets': '4.8.5',
#  'peft': '0.19.1'}

# %%
RUN_MODE = 'PAPER'  # 짧은 점검만 할 때: 'SMOKE'
MAX_JOBS = 1 if RUN_MODE == 'SMOKE' else None
STUDY = 'study2'
print(f'{STUDY=}, {RUN_MODE=}, {MAX_JOBS=}')
# Out:
# STUDY='study2', RUN_MODE='PAPER', MAX_JOBS=None

# %% [markdown]
# ## 실행
#
# 각 run과 epoch가 즉시 디스크에 저장됩니다. 중단 후 이 셀을 다시 실행하면 완료된 run은 자동으로 건너뜁니다.

# %% [markdown]
# result = run_study(STUDY, run_mode=RUN_MODE, max_jobs=MAX_JOBS)
# display(result.tail())

# %%
progress = ROOT / 'results' / STUDY / RUN_MODE / 'progress.json'
print(progress.read_text(encoding='utf-8') if progress.exists() else '아직 진행 파일 없음')
# Out:
# {
#   "study": "study2",
#   "run_mode": "PAPER",
#   "status": "COMPLETE",
#   "total": 450,
#   "completed": 450,
#   "failed": 0,
#   "updated_at": "2026-06-25T22:50:03+09:00"
# }
